# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_data_placement.csv")

# %%
print(df.shape)
df.head()
# Out:
# (500, 3)
#    cgpa  resume_score  placement
# 0  8.00          85.0          1
# 1  7.36          83.0          1
# 2  8.15          75.0          1
# 3  9.02          93.0          1
# 4  7.27          69.0          1

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue= df['placement'], data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:, -1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-19.22,   2.  ]])

# %%
p.intercept_
# Out:
# array([-189.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# c:\Users\irbag\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
